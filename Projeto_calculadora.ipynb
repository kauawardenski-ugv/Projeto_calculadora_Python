# %% [markdown]
# <a href="https://colab.research.google.com/github/ens-lucianoperdona-jpg/Projeto_calculadora_Python/blob/main/Projeto_calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
memoria = 0.0

while True: # opcões para a calculadora
    print("\n Calculadora do Atendente")
    print("1. Adição (+)")
    print("2. Subtração (-)")
    print("3. Multiplicação (*)")
    print("4. Divisão (/)")
    print("5. Porcentagem (%)")
    print("6. Memória + (M+)")
    print("7. Memória - (M-)")
    print("8. Mostrar Memória")
    print("9. Limpar Memória")
    print("0. Sair")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# ...
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
#
# --- 🧮 Calculadora do Atendente ---
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Porcentagem (%)
# 6. Memória + (M+)
# 7. Memória - (M-)
# 8. Mostrar Memória
# 9. Limpar Memória
# 0. Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2982/1183968399.py in <cell line: 0>()
#      14     print("8. Mostrar Memória")
#      15     print("9. Limpar Memória")
# ---> 16     print("0. Sair")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py in write(self, string)
#     548         else:
#     549
# --> 550             is_child = not self._is_master_process()
#     551             # only touch the buffer in the IO thread to avoid races
#     552             with self._buffer_lock:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     436
#     437     def _is_master_process(self):
# --> 438         return os.getpid() == self._master_pid
#     439
#     440     def set_parent(self, parent):
#
# KeyboardInterrupt:
